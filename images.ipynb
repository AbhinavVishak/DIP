# %%
import cPickle as pickle
import numpy as np


import matplotlib.pyplot as plt
# %matplotlib inline

from project_nn import LogisticRegression

from project_utils import *

datasets = load_mnist(theano_shared=False)

test_set_x, test_set_y = datasets[2]


f = open('best_logreg.pkl','rb')
classifier = pickle.load(f)
f.close() 

b = classifier.b.get_value()
w = classifier.W.get_value()

print('Ground Truth')
print( test_set_y[0:10] )

print('Predictions')
print(np.argmax(np.dot( test_set_x[0:10,:] , w ) + b , axis = 1 ) )
    
mis = np.reshape(test_set_x[8] , (28,28 ) )
cor = np.reshape(test_set_x[9] , (28,28 ) )

plt.subplot(1,2,1)
imgplot = plt.imshow( mis )
plt.title('Wrong( GT-5 , pred-6)')
imgplot.set_cmap('Greys')

plt.subplot(1,2,2)
imgplot2 = plt.imshow( cor )
plt.title('Correct - 9 ')
imgplot2.set_cmap('Greys')

plt.savefig('logreg_image.png')

print(w.shape)
plt.figure(2)
for i in range(0,9):
    plt.subplot(3,3,i+1)
    a = plt.imshow( np.reshape(   w[:,i],(28,28)),interpolation="nearest" )
    a.set_cmap('Greys')
    
plt.savefig('lrwts.png')
# Out:
# Ground Truth
# [7 2 1 0 4 1 4 9 5 9]
# Predictions
# [7 2 1 0 4 1 4 9 6 9]
# (784, 10)

# %%
import cPickle as pickle
import numpy as np


import matplotlib.pyplot as plt
# %matplotlib inline

from project_nn import LogisticRegression
from project_nets import plot_mlp
from project_utils import *

plot_mlp()
# Out:
# ... building the model
# Using gpu device 0: GRID K520
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-1-7ff18f07746e> in <module>()
#      10 from project_utils import *
#      11
# ---> 12 plot_mlp()
#
# /home/ubuntu/extern/DIP/project_nets.py in plot_mlp()
#     638
#     639     f = open('best_mlpnl1.pkl','rb')
# --> 640     par = pickle.load( f )
#     641     f.close()
#     642     #classifier.params = par
#
# EOFError:

# %%
import cPickle as pickle
import numpy as np


import matplotlib.pyplot as plt
# %matplotlib inline

from project_nets import plot_lenet


plot_lenet(batch_size =1)
# Out:
# building...
# end
# ()
# (1, 20, 12, 12)
# (1, 50, 4, 4)
# Using gpu device 0: GRID K520
